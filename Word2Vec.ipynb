# %%
import pandas as pd 
import numpy as np

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\joshi\envs\ml-env\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\joshi\envs\ml-env\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\joshi\envs\ml-env\lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\joshi\envs\ml-env\lib\site-packages (from smart_open>=1.8.1->gensim) (2.0.1)

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords

STOP_WORDS = set(stopwords.words('english'))

story = []

for filename in os.listdir('data'):
    with open(os.path.join('data',filename),encoding='latin-1') as f :
        corpus = f.read()
    raw_sentences = sent_tokenize(corpus)
    for sent in raw_sentences:
        tokens = simple_preprocess(sent)
        tokens = [word for word in tokens if word not in STOP_WORDS]
        if tokens :
            story.append(tokens)

# %%
len(story)
# Out:
# 139066

# %%
model = gensim.models.Word2Vec(
    window = 10,
    min_count = 2,
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (4396743, 4579390)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8916825652122498),
#  ('unburnt', 0.8680764436721802),
#  ('viserys', 0.8387354016304016),
#  ('myrcella', 0.8275511860847473),
#  ('court', 0.8064939975738525),
#  ('conspired', 0.8024401664733887),
#  ('elia', 0.8022560477256775),
#  ('queen', 0.7965380549430847),
#  ('targaryen', 0.7949099540710449),
#  ('loraq', 0.7929494380950928)]

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.10831384,  0.07235601,  0.03884977, ..., -0.09057426,
#         -0.1038155 ,  0.21995701],
#        [-0.2263463 ,  0.09643407,  0.13901609, ..., -0.08291601,
#         -0.0661524 ,  0.23578848],
#        [-0.01873031,  0.07578649, -0.03294842, ..., -0.15790817,
#          0.10569072, -0.14924835],
#        ...,
#        [-0.08107498, -0.01820638,  0.022603  , ..., -0.06199161,
#          0.04215246,  0.19441377],
#        [-0.10049238,  0.08581601,  0.12227917, ..., -0.14688405,
#          0.13463616,  0.12554488],
#        [-0.04870157,  0.06352812,  0.15147066, ...,  0.00507409,
#         -0.01069473, -0.02398675]], dtype=float32)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['said',
#  'lord',
#  'would',
#  'one',
#  'ser',
#  'could',
#  'man',
#  'king',
#  'men',
#  'back',
#  'well',
#  'like',
#  'jon',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'tyrion',
#  'never',
#  'know',
#  'see',
#  'made',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'long',
#  'might',
#  'us',
#  'come',
#  'face',
#  'still',
#  'head',
#  'red',
#  'way',
#  'boy',
#  'page',
#  'must',
#  'queen',
#  'good',
#  'two',
#  'brother',
#  'night',
#  'little',
#  'took',
#  'came',
#  'though',
#  'say',
#  'three',
#  'away',
#  'dead',
#  'son',
#  'blood',
#  'take',
#  'go',
#  'half',
#  'make',
#  'arya',
#  'saw',
#  'day',
#  'white',
#  'jaime',
#  'first',
#  'look',
#  'want',
#  'much',
#  'enough',
#  'sword',
#  'tell',
#  'girl',
#  'bran',
#  'great',
#  'looked',
#  'left',
#  'knew',
#  'asked',
#  'gave',
#  'maester',
#  'called',
#  'wall',
#  'every',
#  'heard',
#  'sansa',
#  'let',
#  'yet',
#  'went',
#  'turned',
#  'dany',
#  'need',
#  'behind',
#  'around',
#  'woman',
#  'another',
#  'snow',
#  'beneath',
#  'across',
#  'knight',
#  'keep',
#  'grace',
#  'found',
#  'gold',
#  'last',
#  'cersei',
#  'castle',
#  'stark',
#  'gods',
#  'think',
#  'hair',
#  'many',
#  'feet',
#  'hands',
#  'stannis',
#  'mother',
#  'catelyn',
#  'robert',
#  'seemed',
#  'prince',
#  'may',
#  'ever',
#  'robb',
#  'done',
#  'find',
#  'lannister',
#  'hear',
#  'name',
#  'grey',
#  'horse',
#  'high',
#  'put',
#  'stone',
#  'wine',
#  'hard',
#  'water',
#  'upon',
#  'fire',
#  'iron',
#  'voice',
#  'gone',
#  'give',
#  'sam',
#  'better',
#  'seen',
#  'shall',
#  'ned',
#  'always',
#  'years',
#  'dark',
#  'place',
#  'small',
#  'cold',
#  'winterfell',
#  'hundred',
#  'stood',
#  'end',
#  'sister',
#  'words',
#  'sea',
#  'right',
#  'nothing',
#  'walls',
#  'fingers',
#  'house',
#  'cloak',
#  'young',
#  'beside',
#  'get',
#  'seven',
#  'mouth',
#  'watch',
#  'door',
#  'joffrey',
#  'green',
#  'big',
#  'sent',
#  'perhaps',
#  'almost',
#  'wanted',
#  'daughter',
#  'true',
#  'leave',
#  'city',
#  'wind',
#  'light',
#  'arms',
#  'children',
#  'sweet',
#  'others',
#  'lost',
#  'theon',
#  'felt',
#  'side',
#  'yes',
#  'brothers',
#  'best',
#  'die',
#  'brought',
#  'soon',
#  'died',
#  'far',
#  'north',
#  'child',
#  'fear',
#  'along',
#  'brienne',
#  'word',
#  'taken',
#  'battle',
#  'help',
#  'new',
#  'tywin',
#  'davos',
#  'lords',
#  'something',
#  'mean',
#  'wife',
#  'hall',
#  'rest',
#  'kill',
#  'strong',
#  'steel',
#  'began',
#  'sound',
#  'dragon',
#  'past',
#  'life',
#  'tower',
#  'killed',
#  'arm',
#  'tried',
#  'sons',
#  'free',
#  'thing',
#  'bear',
#  'days',
#  'bloody',
#  'heart',
#  'pale',
#  'love',
#  'moment',
#  'sat',
#  'bring',
#  'bed',
#  'close',
#  'knights',
#  'cut',
#  'wolf',
#  'death',
#  'horses',
#  'smile',
#  'inside',
#  'four',
#  'brown',
#  'dragons',
#  'hot',
#  'silver',
#  'part',
#  'bastard',
#  'open',
#  'thousand',
#  'landing',
#  'uncle',
#  'going',
#  'blue',
#  'captain',
#  'air',
#  'please',
#  'laughed',
#  'river',
#  'sun',
#  'rose',
#  'fell',
#  'war',
#  'golden',
#  'sleep',
#  'without',
#  'swords',
#  'renly',
#  'speak',
#  'certain',
#  'fool',
#  'full',
#  'beyond',
#  'feel',
#  'send',
#  'tongue',
#  'fight',
#  'got',
#  'set',
#  'rode',
#  'thick',
#  'world',
#  'throat',
#  'legs',
#  'deep',
#  'call',
#  'honor',
#  'rock',
#  'trees',
#  'tall',
#  'table',
#  'pulled',
#  'broken',
#  'women',
#  'mormont',
#  'steps',
#  'things',
#  'next',
#  'hodor',
#  'heavy',
#  'burned',
#  'oh',
#  'toward',
#  'together',
#  'skin',
#  'given',
#  'since',
#  'dwarf',
#  'alone',
#  'moved',
#  'smiled',
#  'storm',
#  'raised',
#  'ask',
#  'ride',
#  'eye',
#  'hope',
#  'reached',
#  'soft',
#  'frey',
#  'second',
#  'remember',
#  'someone',
#  'remembered',
#  'coming',
#  'meant',
#  'cannot',
#  'hold',
#  'morning',
#  'ten',
#  'teeth',
#  'else',
#  'throne',
#  'command',
#  'fat',
#  'truth',
#  'walder',
#  'commander',
#  'doubt',
#  'ground',
#  'jorah',
#  'cup',
#  'outside',
#  'known',
#  'wore',
#  'ran',
#  'gate',
#  'room',
#  'held',
#  'closed',
#  'home',
#  'matter',
#  'south',
#  'wood',
#  'sky',
#  'wed',
#  'people',
#  'dozen',
#  'neck',
#  'food',
#  'riverrun',
#  'instead',
#  'near',
#  'turn',
#  'talk',
#  'none',
#  'ships',
#  'tyrell',
#  'moon',
#  'bolton',
#  'lips',
#  'summer',
#  'shadow',
#  'watched',
#  'times',
#  'leather',
#  'varys',
#  'shoulder',
#  'septon',
#  'warm',
#  'caught',
#  'believe',
#  'least',
#  'guards',
#  'answer',
#  'god',
#  'blade',
#  'wondered',
#  'ice',
#  'barristan',
#  'shield',
#  'mine',
#  'opened',
#  'armor',
#  'safe',
#  'six',
#  'kept',
#  'return',
#  'wish',
#  'tommen',
#  'used',
#  'smell',
#  'less',
#  'foot',
#  'squire',
#  'floor',
#  'eddard',
#  'empty',
#  'run',
#  'followed',
#  'serve',
#  'friends',
#  'boys',
#  'beard',
#  'wedding',
#  'cloaks',
#  'baratheon',
#  'eat',
#  'wrong',
#  'daenerys',
#  'ghost',
#  'sight',
#  'hound',
#  'five',
#  'flesh',
#  'ship',
#  'strength',
#  'nose',
#  'returned',
#  'bones',
#  'crown',
#  'yellow',
#  'chest',
#  'covered',
#  'commanded',
#  'says',
#  'petyr',
#  'sometimes',
#  'filled',
#  'aemon',
#  'led',
#  'friend',
#  'aye',
#  'common',
#  'flames',
#  'show',
#  'fighting',
#  'spoke',
#  'asha',
#  'aside',
#  'lysa',
#  'huge',
#  'crow',
#  'belly',
#  'master',
#  'seem',
#  'breath',
#  'yard',
#  'gates',
#  'waiting',
#  'within',
#  'looking',
#  'wooden',
#  'wet',
#  'realm',
#  'thin',
#  'work',
#  'bad',
#  'promised',
#  'use',
#  'husband',
#  'grew',
#  'tree',
#  'later',
#  'onto',
#  'loved',
#  'wildlings',
#  'girls',
#  'greyjoy',
#  'afraid',
#  'rain',
#  'shoulders',
#  'walked',
#  'shouted',
#  'maid',
#  'remained',
#  'mance',
#  'late',
#  'guard',
#  'meereen',
#  'littlefinger',
#  'liked',
#  'fall',
#  'margaery',
#  'dog',
#  'year',
#  'hurt',
#  'passed',
#  'balon',
#  'taste',
#  'dothraki',
#  'drew',
#  'lay',
#  'spear',
#  'realized',
#  'pushed',
#  'song',
#  'named',
#  'sure',
#  'stand',
#  'reach',
#  'brave',
#  'finally',
#  'whispered',
#  'different',
#  'wolves',
#  'suddenly',
#  'poor',
#  'kingsguard',
#  'drogo',
#  'stay',
#  'arryn',
#  'stop',
#  'kingdoms',
#  'edmure',
#  'broke',
#  'ears',
#  'princess',
#  'burning',
#  'faces',
#  'lannisters',
#  'dream',
#  'direwolf',
#  'axe',
#  'west',
#  'heir',
#  'tears',
#  'drink',
#  'clegane',
#  'either',
#  'darkness',
#  'raven',
#  'pointed',
#  'hill',
#  'try',
#  'forward',
#  'pain',
#  'sworn',
#  'khal',
#  'lie',
#  'dagger',
#  'truly',
#  'kings',
#  'seat',
#  'grown',
#  'road',
#  'born',
#  'harrenhal',
#  'care',
#  'bronn',
#  'helm',
#  'round',
#  'feast',
#  'amongst',
#  'meat',
#  'pycelle',
#  'quick',
#  'understand',
#  'longer',
#  'lifted',
#  'whilst',
#  'reminded',
#  'maybe',
#  'mountain',
#  'short',
#  'step',
#  'rodrik',
#  'melisandre',
#  'ones',
#  'pretty',
#  'third',
#  'aegon',
#  'lands',
#  'bit',
#  'stopped',
#  'worse',
#  'sit',
#  'victarion',
#  'save',
#  'sharp',
#  'knows',
#  'whose',
#  'live',
#  'smoke',
#  'horn',
#  'leg',
#  'window',
#  'pray',
#  'younger',
#  'westeros',
#  'twenty',
#  'silk',
#  'heads',
#  'pie',
#  'septa',
#  'peace',
#  'slaves',
#  'ago',
#  'hizdahr',
#  'wants',
#  'bread',
#  'mind',
#  'low',
#  'laugh',
#  'east',
#  'blind',
#  'reek',
#  'towers',
#  'mad',
#  'bright',
#  'sooner',
#  'slain',
#  'coin',
#  'making',
#  'camp',
#  'older',
#  'salt',
#  'drowned',
#  'served',
#  'wait',
#  'narrow',
#  'walk',
#  'point',
#  'glanced',
#  'cousin',
#  'cheeks',
#  'luwin',
#  'knife',
#  'stepped',
#  'shook',
#  'often',
#  'quiet',
#  'sort',
#  'targaryen',
#  'touched',
#  'riding',
#  'loras',
#  'naked',
#  'twisted',
#  'choice',
#  'kevan',
#  'fish',
#  'lion',
#  'forgotten',
#  'silence',
#  'ramsay',
#  'hung',
#  'read',
#  'gift',
#  'running',
#  'fallen',
#  'replied',
#  'large',
#  'knees',
#  'fought',
#  'silent',
#  'cat',
#  'company',
#  'ahead',
#  'beautiful',
#  'rhaegar',
#  'needs',
#  'dawn',
#  'sept',
#  'dogs',
#  'pass',
#  'dorne',
#  'casterly',
#  'knee',
#  'tully',
#  'mud',
#  'gregor',
#  'stupid',
#  'singer',
#  'court',
#  'body',
#  'meera',
#  'age',
#  'trying',
#  'top',
#  'swear',
#  'kind',
#  'gendry',
#  'offered',
#  'whole',
#  'clothes',
#  'leaves',
#  'closer',
#  'kiss',
#  'anything',
#  'whatever',
#  'wonder',
#  'pay',
#  'agreed',
#  'threw',
#  'answered',
#  'climbed',
#  'saying',
#  'wide',
#  'saddle',
#  'stars',
#  'comes',
#  'chain',
#  'trust',
#  'host',
#  'stones',
#  'pleased',
#  'trident',
#  'fair',
#  'yunkai',
#  'spears',
#  'hour',
#  'dry',
#  'dying',
#  'ear',
#  'insisted',
#  'eight',
#  'fast',
#  'carried',
#  'service',
#  'doors',
#  'ought',
#  'mail',
#  'fist',
#  'council',
#  'woods',
#  'thank',
#  'crossed',
#  'join',
#  'needed',
#  'milk',
#  'fine',
#  'wildling',
#  'quentyn',
#  'gilly',
#  'finger',
#  'tent',
#  'shadows',
#  'win',
#  'helped',
#  'land',
#  'bird',
#  'boots',
#  'folk',
#  'crows',
#  'imp',
#  'names',
#  'somehow',
#  'kissed',
#  'letter',
#  'banners',
#  'winter',
#  'pink',
#  'screamed',
#  'angry',
#  'frightened',
#  'torch',
#  'learn',
#  'alive',
#  'chair',
#  'eunuch',
#  'daughters',
#  'watching',
#  'tarly',
#  'harm',
#  'dragonstone',
#  'fires',
#  'serving',
#  'standing',
#  'easy',
#  'neither',
#  'nine',
#  'learned',
#  'wings',
#  'drunk',
#  'question',
#  'myrcella',
#  'priest',
#  'sail',
#  'sisters',
#  'nodded',
#  'harbor',
#  'bone',
#  'giant',
#  'forth',
#  'warned',
#  'field',
#  'slow',
#  'slipped',
#  'slid',
#  'dreams',
#  'bronze',
#  'slowly',
#  'falling',
#  'promise',
#  'atop',
#  'whore',
#  'slave',
#  'illyrio',
#  'line',
#  'move',
#  'rise',
#  'pyke',
#  'makes',
#  'flowers',
#  'laughter',
#  'grass',
#  'faced',
#  'declared',
#  'bay',
#  'earth',
#  'loose',
#  'power',
#  'viserys',
#  'lived',
#  'twice',
#  'front',
#  'cell',
#  'happened',
#  'play',
#  'chains',
#  'oldtown',
#  'break',
#  'dance',
#  'clean',
#  'aerys',
#  'surely',
#  'claim',
#  'unless',
#  'jeyne',
#  'eyrie',
#  'fresh',
#  'cried',
#  'tormund',
#  'craster',
#  'pair',
#  'laid',
#  'quite',
#  'shouting',
#  'morrow',
#  'sad',
#  'met',
#  'game',
#  'already',
#  'rule',
#  'touch',
#  'softly',
#  'steward',
#  'woke',
#  'count',
#  'started',
#  'mounted',
#  'afterward',
#  'sense',
#  'jojen',
#  'captive',
#  'highgarden',
#  'hide',
#  'waters',
#  'sudden',
#  'ravens',
#  'cheek',
#  'taking',
#  'however',
#  'anyone',
#  'course',
#  'follow',
#  'among',
#  'purple',
#  'means',
#  'wench',
#  'noble',
#  'carved',
#  'rickon',
#  'bare',
#  'grenn',
#  'waited',
#  'rising',
#  'murdered',
#  'vale',
#  'thinking',
#  'weak',
#  'cruel',
#  'roose',
#  'roof',
#  'hidden',
#  'eyed',
#  'arrow',
#  'town',
#  'blow',
#  'forest',
#  'wise',
#  'grand',
#  'hungry',
#  'growing',
#  'voices',
#  'today',
#  'army',
#  'sorry',
#  'griff',
#  'tale',
#  'wound',
#  'protect',
#  'cry',
#  'beric',
#  'inn',
#  'twins',
#  'weight',
#  'ugly',
#  'ygritte',
#  'sick',
#  'hoped',
#  'forget',
#  'rolled',
#  'dressed',
#  'knelt',
#  'climb',
#  'enemies',
#  'daario',
#  'chance',
#  'marry',
#  'fur',
#  'seems',
#  'courage',
#  'lad',
#  'grow',
#  'freys',
#  'whether',
#  'fleet',
#  'smiling',
#  'laughing',
#  'bride',
#  'corpse',
#  'marriage',
#  'unsullied',
#  'appeared',
#  'breasts',
#  'meet',
#  'square',
#  'showed',
#  'kingslayer',
#  'drank',
#  'wool',
#  'alayne',
#  'march',
#  'mountains',
#  'mercy',
#  'frozen',
#  'trouble',
#  'edge',
#  'shae',
#  'slynt',
#  'arrows',
#  'wear',
#  'ragged',
#  'decided',
#  'offer',
#  'welcome',
#  'allowed',
#  'swore',
#  'recall',
#  'bound',
#  'sing',
#  'ill',
#  'spread',
#  'everything',
#  'mace',
#  'slept',
#  'seated',
#  'quickly',
#  'wake',
#  'sounded',
#  'tales',
#  'moving',
#  'ancient',
#  'flew',
#  'talking',
#  'dare',
#  'bowed',
#  ...]

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\joshi\envs\ml-env\lib\site-packages (from plotly) (2.13.0)
# Requirement already satisfied: packaging in c:\users\joshi\envs\ml-env\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 217.9 kB/s eta 0:00:43
#    -- ------------------------------------- 0.5/9.9 MB 217.9 kB/s eta 0:00:43
#    -- ------------------------------------- 0.5/9.9 MB 217.9 kB/s eta 0:00:43
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/9.9 MB 270.7 kB/s eta 0:00:34
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ---- ----------------------------------- 1.0/9.9 MB 203.8 kB/s eta 0:00:44
#    ----- ---------------------------------- 1.3/9.9 MB 193.4 kB/s eta 0:00:45
#    ----- ---------------------------------- 1.3/9.9 MB 193.4 kB/s eta 0:00:45
#    ----- ---------------------------------- 1.3/9.9 MB 193.4 kB/s eta 0:00:45
#    ----- ---------------------------------- 1.3/9.9 MB 193.4 kB/s eta 0:00:45
#    ------ --------------------------------- 1.6/9.9 MB 209.2 kB/s eta 0:00:40
#    ------------------------------- -------- 7.9/9.9 MB 246.9 kB/s eta 0:00:09
#    ------------------------------- -------- 7.9/9.9 MB 246.9 kB/s eta 0:00:09
#    ------------------------------- -------- 7.9/9.9 MB 246.9 kB/s eta 0:00:09
#    -------------------------------- ------- 8.1/9.9 MB 248.9 kB/s eta 0:00:08
#    --------------------------------- ------ 8.4/9.9 MB 254.7 kB/s eta 0:00:06
#    --------------------------------- ------ 8.4/9.9 MB 254.7 kB/s eta 0:00:06
#    ---------------------------------- ----- 8.7/9.9 MB 268.5 kB/s eta 0:00:05
#    ---------------------------------- ----- 8.7/9.9 MB 268.5 kB/s eta 0:00:05
#    ---------------------------------- ----- 8.7/9.9 MB 268.5 kB/s eta 0:00:05
#    ------------------------------------ --- 8.9/9.9 MB 271.3 kB/s eta 0:00:04
#    ------------------------------------- -- 9.2/9.9 MB 278.4 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.9 MB 278.4 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.9 MB 278.4 kB/s eta 0:00:03
#    -------------------------------------- - 9.4/9.9 MB 282.4 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.9 MB 282.4 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.9 MB 282.4 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.9 MB 282.4 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.9 MB 289.3 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 293.4 kB/s  0:00:36
# Installing collected packages: plotly
# Successfully installed plotly-6.5.0

# %%
# !pip install --upgrade nbformat
# Out:
# Collecting nbformat
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Using cached fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\joshi\envs\ml-env\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\joshi\envs\ml-env\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\joshi\envs\ml-env\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joshi\envs\ml-env\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joshi\envs\ml-env\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joshi\envs\ml-env\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\joshi\envs\ml-env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Installing collected packages: fastjsonschema, nbformat
#
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    ---------------------------------------- 2/2 [nbformat]
#
# Successfully installed fastjsonschema-2.21.2 nbformat-5.10.4

# %%
# !!pip install --upgrade nbformat
# Out:
# ['Requirement already satisfied: nbformat in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (5.10.4)',
#  'Requirement already satisfied: fastjsonschema>=2.15 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from nbformat) (2.21.2)',
#  'Requirement already satisfied: jsonschema>=2.6 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from nbformat) (4.25.1)',
#  'Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from nbformat) (5.9.1)',
#  'Requirement already satisfied: traitlets>=5.1 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from nbformat) (5.14.3)',
#  'Requirement already satisfied: attrs>=22.2.0 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)',
#  'Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)',
#  'Requirement already satisfied: referencing>=0.28.4 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)',
#  'Requirement already satisfied: rpds-py>=0.7.1 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)',
#  'Requirement already satisfied: platformdirs>=2.5 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)',
#  'Requirement already satisfied: typing-extensions>=4.4.0 in c:\\users\\joshi\\envs\\ml-env\\lib\\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)']

# %%
# !pip install --upgrade ipython
# Out:
# Requirement already satisfied: ipython in c:\users\joshi\envs\ml-env\lib\site-packages (8.37.0)
# Requirement already satisfied: colorama in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\joshi\envs\ml-env\lib\site-packages (from ipython) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\joshi\envs\ml-env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\joshi\envs\ml-env\lib\site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\joshi\envs\ml-env\lib\site-packages (from stack_data->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\joshi\envs\ml-env\lib\site-packages (from stack_data->ipython) (0.2.3)

# %%
import nbformat
print(nbformat.__version__)
# Out:
# 5.10.4

# %%
import plotly.express as px

fig = px.scatter_3d(
    X[:100],
    x=0,
    y=1,
    z=2,
    color=y[:100]
)

fig.show()
